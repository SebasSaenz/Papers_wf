# %%
import pandas as pd
import numpy as np
import os

# %%
def bash(string,name,queue):
  script = "%s.sh"%name
  with open(script, "w") as text_file:
    text_file.write(string)
  # !chmod +x $script
  # !qsub -q $queue $script
  #!rm $script

ws = '/beegfs/work/workspace/ws/ho_kezau83-snakemake-0/'

# %%
pro_gen_cog_int = pd.read_table('Full_table_pro_tax_fun_KEGG_COG_for_PCN.tsv', sep='\t', low_memory=False)

# %%
# !mkdir -p 2_data_processing/1_PCN/PCN_tables_raw

for x in pro_gen_cog_int.columns[3:119]:
    # get columns for this specific column
    pro_gen_cog_sam = pd.DataFrame(pro_gen_cog_int, columns = ['Genus', 'KEGG_COG', x])
    # print(pro_gen_cog_sam.columns)
    # do sum by groups
    pro_gen_cog_sam_sum = pro_gen_cog_sam.groupby(['Genus', 'KEGG_COG']).sum().reset_index()
    # reshape to wide table
    pro_gen_cog_sam_sum_wide = pro_gen_cog_sam_sum.pivot(index='KEGG_COG', columns='Genus', values= x )
    # write to tables
    pro_gen_cog_sam_sum_wide.to_csv('2_data_processing/1_PCN/PCN_tables_raw/'+ x + '.csv')
    print(x)

# %%
#Step 5. Generate 0 1 PCN tables
### Batch process files - from genus to COG tables, generate an overall PCN and individual sample PCNs ########
# !mkdir -p 2_data_processing/1_PCN/PCN_tables_0_1

def findfile(path, tagstr):
    #setup an empty dataframe with same index and column names as all tables
    path = os.path.abspath(path)
    for x in os.listdir(path):
        fulldir = os.path.join(path, x)  # join to absolute path
        if os.path.isfile(fulldir):  # file, match -> print
            # if os.path.split(fulldir)[1]==tagstr   # look for the designated file
            if tagstr in os.path.splitext(fulldir)[1]:  # look for files containing the key word
                print(os.path.join(os.path.abspath(fulldir), fulldir))
                PCN_table_single = pd.read_table(fulldir, delimiter=",").set_index(['KEGG_COG']).fillna(0).T
                if_detected = PCN_table_single.astype('float') > 0
                PCN_table_single['num_detected'] = if_detected.sum(axis=1)
                PCN_table_single_filtered = PCN_table_single.loc[(PCN_table_single.sum(axis=1) != 0), (PCN_table_single.sum(axis=0) != 0)].\
                    sort_values(by ='num_detected', ascending=False).drop(columns='num_detected') #remove empty columns for individual files
                PCN_table_single_filtered = PCN_table_single_filtered.astype(
                    'float') > 0  # replace values with presence or not (1 or 0), it will give a True or False value
                PCN_table_single_filtered = PCN_table_single_filtered.astype('float')  # replace True or False with 1 or 0
                PCN_table_single_filtered_sum = pd.DataFrame(PCN_table_single_filtered.sum(axis=0)).rename(columns={0: 'sum_num'}).T
                PCN_table_single_filtered_sum_col = pd.concat([PCN_table_single_filtered, PCN_table_single_filtered_sum]).sort_values(by='sum_num', axis=1,
                                                                                            ascending=False).drop(
                    index='sum_num') # get sorted PCN for each individual sample
                PCN_table_single_filtered_sum_col.to_csv('2_data_processing/1_PCN/PCN_tables_0_1/' + os.path.splitext(x)[0] + '.csv')

findfile('2_data_processing/1_PCN/PCN_tables_raw/', '.csv')

# %%
## Part 2. Degree distributions
# Degree distributions
# !mkdir -p 2_data_processing/2_Degree_distribution/Taxon
# !mkdir -p 2_data_processing/2_Degree_distribution/Function

def findfile(path, tagstr):
    path = os.path.abspath(path)

    for x in os.listdir(path):

        fulldir = os.path.join(path, x)  # join to absolute path

        if os.path.isfile(fulldir):  # file, match -> print
            # if os.path.split(fulldir)[1]==tagstr   # look for the designated file
            if tagstr in os.path.splitext(fulldir)[1]:  # look for files containing the key word
                print(os.path.join(os.path.abspath(fulldir), fulldir))

                ######## Calculation starts here ###############################
                origin_data = pd.read_table(fulldir, delimiter=",", index_col=0)           #read a PCN_0_1 table

                taxon_degree_distribution = pd.DataFrame()
                COG_degree_distribution = pd.DataFrame()

                # calculate number of nodes k degree
                taxon_degree_distribution['k'] = origin_data.sum(axis=1)
                COG_degree_distribution['k'] = origin_data.sum(axis=0)

                # calculate pk fraction of nodes
                taxon_pk = pd.DataFrame(columns=['k'])
                taxon_pk['pk'] = taxon_degree_distribution['k'].value_counts() / len(taxon_degree_distribution.index)
                taxon_pk['k'] = taxon_pk.index
                taxon_degree_distribution = taxon_pk.merge(taxon_degree_distribution, on='k')

                COG_pk = pd.DataFrame(columns=['k'])
                COG_pk['pk'] = COG_degree_distribution['k'].value_counts() / len(COG_degree_distribution.index)
                COG_pk['k'] = COG_pk.index
                COG_degree_distribution = COG_pk.merge(COG_degree_distribution, on='k')

                taxon_degree_distribution.to_csv('2_data_processing/2_Degree_distribution/Taxon/'+ x)
                COG_degree_distribution.to_csv('2_data_processing/2_Degree_distribution/Function/'+ x)


findfile('2_data_processing/1_PCN/PCN_tables_0_1', '.csv')

# %%
file_list = os.listdir('2_data_processing/1_PCN/PCN_tables_raw/')

# %%
file_list = ['Seifert_Hammel_Nr001.csv']

# %%
# Set the index properly to SET NAME
### Part 3. deep MP dataset, all genera, functional distance ###
# the results will be used for FR calculation, but not for dij visualization
string = '''
#PBS -l nodes=1:ppn=14
#PBS -l walltime=8:00:00
#PBS -l mem=64gb
#PBS -S /bin/bash
source /beegfs/work/workspace/ws/ho_kezau83-conda-0/conda/etc/profile.d/conda.sh
conda activate fr-metalab

python /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/untitled.py %s

conda deactivate
'''
# !mkdir -p 2_data_processing/3_PCN_Functional_distance/all/norm/matrix/
# !mkdir -p 2_data_processing/3_PCN_Functional_distance/all/norm/list

for file in file_list:
    file = ws + '2_data_processing/1_PCN/PCN_tables_raw/%s' % file
    bash(string%(file),'%s_fr-metalab'%file,'short')

# %%
# !qstat -u ho_kezau83

# %%
#The index means to get the sample name, this can be improve


# Calculates functional redundancy following this equation:
# FR = ∑(N,i=1)∑(N,j=1)(1-dij)pipj

## loop for all samples - deep metaproteomics
######## Batch process files - calculating Dij for each sample ########
# !mkdir -p 2_data_processing/4_Functional_redundancy/

genus_table_original = pd.read_table("Taxonomy_table_genus_level_metaproteomics.tsv",
                                     delimiter="\t", index_col=0)
genus_table_p_matrix = genus_table_original.div(genus_table_original.sum(axis=0), axis=1)

## loop for all samples - deep metaproteomics
######## Batch process files - calculating Dij for each sample ########
def findfile(path, tagstr):
    Record_FR = pd.DataFrame()
    Record_FR_norm = pd.DataFrame()
    count = 0

    path = os.path.abspath(path)

    for x in os.listdir(path):

        fulldir = os.path.join(path, x)  # join to absolute path

        if os.path.isfile(fulldir):  # file, match -> print
            # if os.path.split(fulldir)[1]==tagstr   # look for the designated file
            if tagstr in os.path.splitext(fulldir)[1]:  # look for files containing the key word
                print(os.path.join(os.path.abspath(fulldir), fulldir))

                ######## Calculation starts here ###############################
                dij_table_data = pd.read_table(fulldir, delimiter=",", index_col=0)
                dij_table_data_indexed = pd.concat(
                    [dij_table_data, dij_table_data["VS"].str.split("_vs_", n=1, expand=True)], axis=1).rename(
                    columns={0: "i", 1: "j"})
                # index to the sample column in the genus_table_p_matrix
                genus_table_p_sample_i = genus_table_p_matrix[[x[-24:-4]]].rename(columns={x[-24:-4]: 'Abundance'})
                genus_table_p_sample_j = genus_table_p_matrix[[x[-24:-4]]].rename(columns={x[-24:-4]: 'Abundance'})

                # assign pi and pj values to the data table
                genus_table_p_sample_i = genus_table_p_sample_i.reset_index().rename(columns={'Name': "i"})
                genus_table_p_sample_j = genus_table_p_sample_j.reset_index().rename(columns={'Name': "j"})
                dij_table_trial_indexed_p = dij_table_data_indexed.merge(genus_table_p_sample_i, on='i').rename(
                    columns={'Abundance': 'pi'})
                dij_table_trial_indexed_p = dij_table_trial_indexed_p.merge(genus_table_p_sample_j, on='j').rename(
                    columns={'Abundance': 'pj'})

                # Calculate (1-dij)pipj
                FR = 0
                GSI = 0
                for x in dij_table_trial_indexed_p.index:
                    FR_ij = (1 - dij_table_trial_indexed_p.loc[x, 'dij_list']) * dij_table_trial_indexed_p.loc[
                        x, 'pi'] * dij_table_trial_indexed_p.loc[x, 'pj']
                    FR = FR + FR_ij * 2
                    # Taxonomic diversity: Gini-Simpson index
                    GSI_ij = dij_table_trial_indexed_p.loc[x, 'pi'] * dij_table_trial_indexed_p.loc[x, 'pj']
                    GSI = GSI + GSI_ij * 2
                print(FR)
                print(GSI)
                Record_FR.loc[count, 0] = fulldir[-9:-4]
                Record_FR.loc[count, 1] = FR
                Record_FR.loc[count, 2] = FR/GSI # Functional redundancy normalized by taxonomic diveristy
                Record_FR.loc[count, 3] = GSI
                Record_FR.loc[count, 4] = GSI-FR
                count = count + 1

    Record_FR.rename(columns={0: "Sample", 1: "FR", 2: "nFR", 3: "TD", 4: "FD"}).to_csv('2_data_processing/4_Functional_redundancy/' + 'Record_FR_PCN.csv')


findfile('2_data_processing/3_PCN_Functional_distance/all/norm/list', '.csv')
# Out:
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr084.csv
# 0.07486511593385148
# 0.9735462027583618
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr025.csv
# 0.06193065053855085
# 0.9576402783304436
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr077.csv
# 0.08717395947468791
# 0.9712188849236459
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr102.csv
# 0.07594424407630994
# 0.9804484890978615
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr043.csv
# 0.06859066217184812
# 0.982237217301352
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr079.csv
# 0.06354183380521931
# 0.9781685010897094
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr090.csv
# 0.05182587452302817
# 0.9351309965440003
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr083.csv
# 0.06325523422089362
# 0.9824199785097111
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr123.csv
# 0.0712747808643308
# 0.9811303705884136
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr126.csv
# 0.07233278758556866
# 0.981777808533428
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr047.csv
# 0.07722124851968187
# 0.981276330694545
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr089.csv
# 0.055749783453685246
# 0.9695185850504888
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr118.csv
# 0.04789023492426809
# 0.9819686291602138
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr092.csv
# 0.061054002322676645
# 0.9553089384716648
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr009.csv
# 0.06262088985296095
# 0.981954276638812
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr101.csv
# 0.07960449594601107
# 0.9791217742649597
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr020.csv
# 0.08117406363623166
# 0.9756483318089781
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr006.csv
# 0.08408760791179563
# 0.9703202211776628
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr021.csv
# 0.08159536280312332
# 0.9724100356754741
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr014.csv
# 0.07874660497589744
# 0.9558283561029686
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr091.csv
# 0.06311115228437218
# 0.9373621126792835
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr055.csv
# 0.08169980130240732
# 0.9730928481115927
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr036.csv
# 0.05107735256584017
# 0.9673089366221769
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr050.csv
# 0.06844149260625224
# 0.9804870945506415
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr063.csv
# 0.060572668562294825
# 0.9708902499367279
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr067.csv
# 0.05916433143192715
# 0.9572041885679982
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr027.csv
# 0.04494904639674914
# 0.9568489769099937
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr052.csv
# 0.06048608939453315
# 0.9819372246758586
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr048.csv
# 0.0717352169185264
# 0.9755249747277969
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr054.csv
# 0.08044401488919194
# 0.9754262614942978
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr095.csv
# 0.05969033283125545
# 0.9710241105106919
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr037.csv
# 0.07615330300963481
# 0.9659245132356418
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr040.csv
# 0.07215265044791704
# 0.9777322992038855
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr053.csv
# 0.07511204263439505
# 0.9773649863893512
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr003.csv
# 0.08024145771969468
# 0.9658248283286545
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr013.csv
# 0.0694034857871138
# 0.9636154155969269
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr032.csv
# 0.057236310714739766
# 0.9590209827937605
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr042.csv
# 0.08682059054703004
# 0.9743273628152854
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr019.csv
# 0.08611841691246729
# 0.9627087162036084
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr098.csv
# 0.058665448671960656
# 0.9353300714655982
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr030.csv
# 0.06039910564678544
# 0.9823962781460736
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr105.csv
# 0.08172553699210461
# 0.9748916944805366
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr007.csv
# 0.08523371389587117
# 0.9739771208383241
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr012.csv
# 0.07817296020828983
# 0.981411313767654
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr018.csv
# 0.08028401818893197
# 0.9782366146405977
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr086.csv
# 0.08009929938504239
# 0.9739820066966256
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr065.csv
# 0.06865789989923815
# 0.9814257919207445
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr057.csv
# 0.08222997504171418
# 0.9735563560927009
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr051.csv
# 0.05816310065691927
# 0.9782458906461724
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr056.csv
# 0.07790901001779717
# 0.9721209064584282
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr026.csv
# 0.05427545741943585
# 0.974649371902175
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr066.csv
# 0.05403173221280612
# 0.9317350044317005
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr035.csv
# 0.06161243967958448
# 0.9319089997796868
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr096.csv
# 0.05847940630436361
# 0.973274796300944
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr071.csv
# 0.055562093224215056
# 0.9800609262122072
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr008.csv
# 0.06853199797985775
# 0.9818200244294303
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr068.csv
# 0.058178732217351245
# 0.9761241135475013
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr034.csv
# 0.04517784714980794
# 0.9631844805076955
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr024.csv
# 0.04779809251932246
# 0.9500762792376196
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr100.csv
# 0.07117098237986914
# 0.9772352499936868
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr073.csv
# 0.08308806498407278
# 0.9726998139467805
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr097.csv
# 0.05284678575825927
# 0.9609820887256803
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr085.csv
# 0.07111531777362967
# 0.9736414731452843
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr061.csv
# 0.07081534893531176
# 0.978240717864032
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr039.csv
# 0.07540413961999434
# 0.9788581926463735
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr069.csv
# 0.04170632939016569
# 0.9651943345490192
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr113.csv
# 0.04987419611873164
# 0.9713087219157819
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr080.csv
# 0.07041041942088659
# 0.9798657889824399
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr081.csv
# 0.07188939311727037
# 0.9810869575906036
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr104.csv
# 0.0823651846022854
# 0.9757254709078126
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr099.csv
# 0.052333223214884074
# 0.9499031321850426
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr070.csv
# 0.0563879862805245
# 0.9657455753522185
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr072.csv
# 0.07217877128024809
# 0.9751650099708037
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr023.csv
# 0.0875566635330085
# 0.9501951778114712
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr076.csv
# 0.08224730901298483
# 0.9598104296416154
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr002.csv
# 0.06798195280998888
# 0.9780497123193642
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr016.csv
# 0.06599595882358204
# 0.9822077774265358
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr064.csv
# 0.06001252820970571
# 0.9677439262268832
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr074.csv
# 0.07778341981674282
# 0.9800256294487267
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr094.csv
# 0.053285267923263886
# 0.9527202547297787
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr060.csv
# 0.0626540144894302
# 0.9710893044276995
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr015.csv
# 0.07469490599451258
# 0.9766535170664551
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr010.csv
# 0.06693051583934609
# 0.9767579232904736
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr005.csv
# 0.07821202394214834
# 0.9763312884642988
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr114.csv
# 0.04400671409771362
# 0.9769231097833811
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr045.csv
# 0.0718597795877725
# 0.9787773105768687
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr088.csv
# 0.057631382022584624
# 0.9792246675602426
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr093.csv
# 0.06389384072332409
# 0.9821276887658487
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr033.csv
# 0.05719065806496381
# 0.9788333619473099
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr038.csv
# 0.07854479558704354
# 0.9734651573118599
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr004.csv
# 0.07406876003860685
# 0.9814448225059548
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr058.csv
# 0.08771139812903571
# 0.9619318117079165
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr046.csv
# 0.07869308515480354
# 0.9806204504554635
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr029.csv
# 0.05862052765609595
# 0.9803765826153519
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr103.csv
# 0.08140835674454606
# 0.9752232826018883
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr022.csv
# 0.0838398473427006
# 0.9685590346970093
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr062.csv
# 0.048630028863573725
# 0.9506352048231048
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr125.csv
# 0.06965066375121798
# 0.9823664874559767
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr121.csv
# 0.06518242252667676
# 0.9821872283244857
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr122.csv
# 0.0722691235480522
# 0.9812079938037909
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr082.csv
# 0.06254874699143638
# 0.982208395382682
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr001.csv
# 0.06079226851902399
# 0.9824942251380463
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr044.csv
# 0.06454422432319294
# 0.9822738923819327
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr075.csv
# 0.07530851808476333
# 0.9781899872265379
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr041.csv
# 0.08287376406525135
# 0.9718492299706647
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr017.csv
# 0.06088041718295863
# 0.9824567781099489
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr011.csv
# 0.07850666177049949
# 0.9757903286709122
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr119.csv
# 0.06974157771798424
# 0.9824428214766225
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr059.csv
# 0.05205657367931131
# 0.9205835993513023
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr124.csv
# 0.05741137067814364
# 0.9828842780890971
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr120.csv
# 0.05917020098146729
# 0.9817881365707497
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr031.csv
# 0.05331634296234369
# 0.9644250660278811
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr028.csv
# 0.06270077116607456
# 0.944242538414411
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr116.csv
# 0.06079857236890786
# 0.969274170384398
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr115.csv
# 0.042487975829030196
# 0.9796661514368717
# /beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr117.csv
# 0.04901220738573472
# 0.9635365863312536

# %%
x[-16:-4]

# %%
x = "/beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr019.csv"

genus_table_original = pd.read_table("Taxonomy_table_genus_level_metaproteomics.tsv",
                                     delimiter="\t", index_col=0)
genus_table_p_matrix = genus_table_original.div(genus_table_original.sum(axis=0), axis=1)
genus_table_p_sample_i = genus_table_p_matrix[[x[-24:-4]]].rename(columns={x[-29:-4]: 'Abundance'})

# %%
genus_table_p_matrix
# Out:
#                Seifert_Hammel_Nr001  Seifert_Hammel_Nr010  \
# Name
# 12844                      0.001885              0.001446
# 51-20                      0.000000              0.000000
# AC2028                     0.005556              0.004067
# Absicoccus                 0.000029              0.000014
# Acetatifactor              0.002927              0.002532
# ...                             ...                   ...
# WCHB1-69                   0.000092              0.000139
# Weimerbacter               0.000654              0.000330
# XBB2008                    0.000014              0.000000
# Zag1                       0.000015              0.000001
# Zag111                     0.000013              0.000005
#
#                Seifert_Hammel_Nr100  Seifert_Hammel_Nr101  \
# Name
# 12844                      0.000843              0.001112
# 51-20                      0.000000              0.000000
# AC2028                     0.003233              0.004446
# Absicoccus                 0.000039              0.000040
# Acetatifactor              0.001831              0.002515
# ...                             ...                   ...
# WCHB1-69                   0.000099              0.000124
# Weimerbacter               0.000330              0.000568
# XBB2008                    0.000019              0.000000
# Zag1                       0.000307              0.000009
# Zag111                     0.000010              0.000015
#
#                Seifert_Hammel_Nr102  Seifert_Hammel_Nr103  \
# Name
# 12844                      0.001268              0.001243
# 51-20                      0.000002              0.000004
# AC2028                     0.003719              0.003703
# Absicoccus                 0.000050              0.000017
# Acetatifactor              0.003319              0.002996
# ...                             ...                   ...
# WCHB1-69                   0.000104              0.000233
# Weimerbacter               0.000374              0.000365
# XBB2008                    0.000022              0.000000
# Zag1                       0.000004              0.000108
# Zag111                     0.000018              0.000004
#
#                Seifert_Hammel_Nr104  Seifert_Hammel_Nr105  \
# Name
# 12844                      0.000552              0.000876
# 51-20                      0.000000              0.000000
# AC2028                     0.004875              0.003752
# Absicoccus                 0.000035              0.000021
# Acetatifactor              0.002827              0.003620
# ...                             ...                   ...
# WCHB1-69                   0.000132              0.000175
# Weimerbacter               0.000830              0.000274
# XBB2008                    0.000000              0.000002
# Zag1                       0.000004              0.000014
# Zag111                     0.000018              0.000017
#
#                Seifert_Hammel_Nr011  Seifert_Hammel_Nr113  ...  \
# Name                                                       ...
# 12844                      0.001484              0.001487  ...
# 51-20                      0.000011              0.000000  ...
# AC2028                     0.006204              0.004769  ...
# Absicoccus                 0.000112              0.000166  ...
# Acetatifactor              0.004093              0.002437  ...
# ...                             ...                   ...  ...
# WCHB1-69                   0.000104              0.000034  ...
# Weimerbacter               0.001204              0.000622  ...
# XBB2008                    0.000002              0.000000  ...
# Zag1                       0.000155              0.000008  ...
# Zag111                     0.000009              0.000002  ...
#
#                Seifert_Hammel_Nr090  Seifert_Hammel_Nr091  \
# Name
# 12844                      0.000831              0.000986
# 51-20                      0.000003              0.000000
# AC2028                     0.002944              0.005266
# Absicoccus                 0.000015              0.000048
# Acetatifactor              0.002133              0.002851
# ...                             ...                   ...
# WCHB1-69                   0.000183              0.000060
# Weimerbacter               0.000666              0.000479
# XBB2008                    0.000000              0.000018
# Zag1                       0.000005              0.000017
# Zag111                     0.000033              0.000022
#
#                Seifert_Hammel_Nr092  Seifert_Hammel_Nr093  \
# Name
# 12844                      0.000945              0.001519
# 51-20                      0.000004              0.000002
# AC2028                     0.003947              0.004840
# Absicoccus                 0.000051              0.000047
# Acetatifactor              0.003305              0.004343
# ...                             ...                   ...
# WCHB1-69                   0.000055              0.000094
# Weimerbacter               0.000446              0.000481
# XBB2008                    0.000000              0.000000
# Zag1                       0.000000              0.000020
# Zag111                     0.000034              0.000035
#
#                Seifert_Hammel_Nr094  Seifert_Hammel_Nr095  \
# Name
# 12844                      0.000468              0.001317
# 51-20                      0.000002              0.000000
# AC2028                     0.001920              0.006327
# Absicoccus                 0.000032              0.000290
# Acetatifactor              0.001405              0.001916
# ...                             ...                   ...
# WCHB1-69                   0.000041              0.000032
# Weimerbacter               0.000270              0.001556
# XBB2008                    0.000000              0.000018
# Zag1                       0.000003              0.000012
# Zag111                     0.000047              0.000015
#
#                Seifert_Hammel_Nr096  Seifert_Hammel_Nr097  \
# Name
# 12844                  9.032201e-04              0.001833
# 51-20                  9.023978e-07              0.000000
# AC2028                 3.117098e-03              0.002873
# Absicoccus             3.396622e-05              0.000014
# Acetatifactor          1.937915e-03              0.002741
# ...                             ...                   ...
# WCHB1-69               3.063599e-05              0.000059
# Weimerbacter           4.501783e-04              0.000325
# XBB2008                1.524981e-05              0.000000
# Zag1                   7.132087e-06              0.000000
# Zag111                 1.333792e-05              0.000002
#
#                Seifert_Hammel_Nr098  Seifert_Hammel_Nr099
# Name
# 12844                      0.001359              0.000921
# 51-20                      0.000001              0.000000
# AC2028                     0.003173              0.003386
# Absicoccus                 0.000042              0.000033
# Acetatifactor              0.002448              0.002112
# ...                             ...                   ...
# WCHB1-69                   0.000019              0.000042
# Weimerbacter               0.001013              0.000538
# XBB2008                    0.000003              0.000000
# Zag1                       0.000036              0.000004
# Zag111                     0.000008              0.000012
#
# [428 rows x 116 columns]

# %%
# !ls 2_data_processing/3_PCN_Functional_distance/all/norm/matrix/ |

# %%
# !rm -r 2_data_processing/

# %%
file_path = "/beegfs/work/workspace/ws/ho_kezau83-snakemake-0/2_data_processing/3_PCN_Functional_distance/all/norm/list/all_norm_dij_list_Seifert_Hammel_Nr019.csv"
x = file_path[-24:-4]
x
# Out:
# 'Seifert_Hammel_Nr019'

# %%
# !rename ifert Seifert 2_data_processing/3_PCN_Functional_distance/all/norm/list/*.csv
